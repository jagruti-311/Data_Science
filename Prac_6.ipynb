# %% [markdown]
# <a href="https://colab.research.google.com/github/jagruti-311/Data_Science/blob/main/Prac_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing dataset from seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #Dropping

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_oper=df.drop('deck',axis=1)

# %%
df_oper.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df_oper=df.drop(['deck','sibsp'],axis=1)

# %%
df_oper.head()
# Out:
#    survived  pclass     sex   age  parch     fare embarked  class    who  \
# 0         0       3    male  22.0      0   7.2500        S  Third    man
# 1         1       1  female  38.0      0  71.2833        C  First  woman
# 2         1       3  female  26.0      0   7.9250        S  Third  woman
# 3         1       1  female  35.0      0  53.1000        S  First  woman
# 4         0       3    male  35.0      0   8.0500        S  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
df_oper=df.drop([2,3],axis=0)

# %%
df_oper.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True

# %% [markdown]
# #Renaming a column in a dataset

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df_oper=df.rename(columns={'fare':'price'})

# %%
df_oper.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch    price embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_oper=df.rename(columns={'fare':'price','sex':'gender'})

# %%
df_oper.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch    price embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #Selecting columns with specific datatypes

# %%
df_oper=df.select_dtypes('int')

# %%
df_oper.head()
# Out:
#    survived  pclass  sibsp  parch
# 0         0       3      1      0
# 1         1       1      1      0
# 2         1       3      0      0
# 3         1       1      1      0
# 4         0       3      0      0

# %%
df_oper=df.select_dtypes('float')

# %%
df_oper.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df_oper=df.select_dtypes('object')

# %%
df_oper.head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %% [markdown]
# #Slicing the dataset (calling dataset in a proper range)

# %%
df.iloc[:5,0]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
df.loc[:5,'fare']
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# Name: fare, dtype: float64

# %% [markdown]
# #Handle duplicates in a dataset

# %%
df_oper.drop_duplicates()
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 5      male        Q    man   Queenstown    no
# 7      male        S  child  Southampton    no
# 9    female        C  child    Cherbourg   yes
# 10   female        S  child  Southampton   yes
# 14   female        S  child  Southampton    no
# 16     male        Q  child   Queenstown    no
# 17     male        S    man  Southampton   yes
# 18   female        S  woman  Southampton    no
# 22   female        Q  child   Queenstown   yes
# 26     male        C    man    Cherbourg    no
# 28   female        Q  woman   Queenstown   yes
# 36     male        C    man    Cherbourg   yes
# 61   female      NaN  woman          NaN   yes
# 78     male        S  child  Southampton   yes
# 111  female        C  child    Cherbourg    no
# 114  female        C  woman    Cherbourg    no
# ...

# %% [markdown]
# #Select specific values from the column

# %%
df_oper[df['embarked']=='Q']
# Out:
#         sex embarked    who embark_town alive
# 5      male        Q    man  Queenstown    no
# 16     male        Q  child  Queenstown    no
# 22   female        Q  child  Queenstown   yes
# 28   female        Q  woman  Queenstown   yes
# 32   female        Q  woman  Queenstown   yes
# ..      ...      ...    ...         ...   ...
# 790    male        Q    man  Queenstown    no
# 825    male        Q    man  Queenstown    no
# 828    male        Q    man  Queenstown   yes
# 885  female        Q  woman  Queenstown    no
# 890    male        Q    man  Queenstown    no
#
# [77 rows x 5 columns]

# %%
df_oper['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
dfr=(df_oper['embarked']).isin

# %% [markdown]
# #Group_by in DataFrame

# %%
df.groupby('sex').agg({'fare':'count'})
# Out:
#         fare
# sex
# female   314
# male     577

# %%
df.groupby('sex').agg({'age':'mean'})
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
df.groupby(['pclass','sex']).agg({'fare':'count'})
# Out:
#                fare
# pclass sex
# 1      female    94
#        male     122
# 2      female    76
#        male     108
# 3      female   144
#        male     347

# %% [markdown]
# #Mapping in pandas

# %%
df['survived'].map(lambda x:'survived' if x==1 else 'not survived')
# Out:
# 0      not survived
# 1          survived
# 2          survived
# 3          survived
# 4      not survived
#            ...
# 886    not survived
# 887        survived
# 888    not survived
# 889        survived
# 890    not survived
# Name: survived, Length: 891, dtype: object

# %% [markdown]
# #Replace

# %%
df['sex'].replace(['male','female'],['m','f'])
# Out:
# 0      m
# 1      f
# 2      f
# 3      f
# 4      m
#       ..
# 886    m
# 887    f
# 888    f
# 889    m
# 890    m
# Name: sex, Length: 891, dtype: object

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'])
plt.show()

# %%
df['sex']=df['sex'].fillna(29)

# %%
import matplotlib.pyplot as plt
plt.hist(df['age'])
plt.show()

# %%
df.groupby('who').agg({'who':'count'})
# Out:
#        who
# who
# child   83
# man    537
# woman  271

# %%
df.groupby(['sex','who']).agg({'who':'count'})
# Out:
#               who
# sex    who
# female child   43
#        woman  271
# male   child   40
#        man    537
