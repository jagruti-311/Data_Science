# %% [markdown]
# <a href="https://colab.research.google.com/github/jagruti-311/Data_Science/blob/main/prac7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading data from different source files formats (csv,excel)

# %%
import pandas as pd
data=pd.read_csv('/content/mydata.csv')

# %%
data
# Out:
#     SR.NO       NAME       DEPT  SALARY
# 0       1    JAGRUTI        ACT   45000
# 1       2   PRIYANKA         HR   45000
# 2       3   JAISHREE         HR   40000
# 3       4     SAYALI      SALES   50000
# 4       5     SAKSHI      SALES   46000
# 5       6     SIDDHU        MGT   34000
# 6       7      SAHIL         IT   23000
# 7       8   SHRADDHA         IT   42000
# 8       9      ROHIT  INVENTORY   56000
# 9      10      SEJAL         HR   65000
# 10     11  PRATHMESH        ACT   50000
# 11     12     ANKITA        ACT   50000
# 12     13      ALMAS        MGT   76000
# 13     14       TANU        MGT   54000
# 14     15  DHANSHREE      SALES   40000

# %%
data1=pd.read_excel('/content/mydata.xlsx')

# %%
data1
# Out:
#     SR.NO       NAME       DEPT  SALARY
# 0       1    JAGRUTI        ACT   45000
# 1       2   PRIYANKA         HR   45000
# 2       3   JAISHREE         HR   40000
# 3       4     SAYALI      SALES   50000
# 4       5     SAKSHI      SALES   46000
# 5       6     SIDDHU        MGT   34000
# 6       7      SAHIL         IT   23000
# 7       8   SHRADDHA         IT   42000
# 8       9      ROHIT  INVENTORY   56000
# 9      10      SEJAL         HR   65000
# 10     11  PRATHMESH        ACT   50000
# 11     12     ANKITA        ACT   50000
# 12     13      ALMAS        MGT   76000
# 13     14       TANU        MGT   54000
# 14     15  DHANSHREE      SALES   40000

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('/content/feather.jpg')
plt.imshow(img)

# %% [markdown]
# #**Summerising The Data**

# %%
import seaborn as sns
import pandas as pd
data=pd.DataFrame({'Roll no':[1,2,3,4,5,6],'Name':['Jagruti','priyanka','Almas','Tanu','Jaishree','Ankita']
                   ,'Marks':[60,58,55,52,53,54],'Class':['B','A','B','A','B','A']})

# %%
print(data)
# Out:
#    Roll no      Name  Marks Class
# 0        1   Jagruti     60     B
# 1        2  priyanka     58     A
# 2        3     Almas     55     B
# 3        4      Tanu     52     A
# 4        5  Jaishree     53     B
# 5        6    Ankita     54     A

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# Class      0
# dtype: int64

# %%
data.describe()
# Out:
#         Roll no      Marks
# count  6.000000   6.000000
# mean   3.500000  55.333333
# std    1.870829   3.076795
# min    1.000000  52.000000
# 25%    2.250000  53.250000
# 50%    3.500000  54.500000
# 75%    4.750000  57.250000
# max    6.000000  60.000000

# %%
data.describe(include='object')
# Out:
#            Name Class
# count         6     6
# unique        6     2
# top     Jagruti     B
# freq          1     3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  6 non-null      int64
#  1   Name     6 non-null      object
#  2   Marks    6 non-null      int64
#  3   Class    6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    6
# Name       6
# Marks      6
# Class      2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: Name, dtype: bool

# %%
data['Name'].value_counts()
# Out:
# Jagruti     1
# priyanka    1
# Almas       1
# Tanu        1
# Jaishree    1
# Ankita      1
# Name: Name, dtype: int64

# %%
data.value_counts()
# Out:
# Roll no  Name      Marks  Class
# 1        Jagruti   60     B        1
# 2        priyanka  58     A        1
# 3        Almas     55     B        1
# 4        Tanu      52     A        1
# 5        Jaishree  53     B        1
# 6        Ankita    54     A        1
# dtype: int64

# %%
data['Class'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: Class, dtype: bool

# %%
data['Class'].value_counts()
# Out:
# B    3
# A    3
# Name: Class, dtype: int64

# %%
data['Marks'].mean()
# Out:
# 55.333333333333336

# %%
data['Marks'].var()
# Out:
# 9.466666666666669

# %%
correlation=data.corr()
# Out:
# <ipython-input-29-7f2487af4b08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >
